# %% [markdown]
# <a href="https://colab.research.google.com/github/dhiraj-vrit/dsml_batch_9/blob/Madan_Khanal/Day04_List%2CTuples%2CSet%2CDictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fruits = ["orange", "mango", "watermelon", "banana"]
print(type(fruits))
# Out:
# <class 'list'>

# %%
fruits1 = ("orange", "mango", "watermelon", "banana")
print(type(fruits1))
# Out:
# <class 'tuple'>

# %%
set1={"orange", "mango", "watermelon", "banana"}
print(type(set1))
# Out:
# <class 'set'>

# %%
new_conversion=set(fruits)
print(type(new_conversion))
# Out:
# <class 'set'>

# %%
number=[1,2,3,4,5,6,1,2,3]
print(type(number))
# Out:
# <class 'list'>

# %%
new_tuple=tuple(number)
print(type(new_tuple))
# Out:
# <class 'tuple'>

# %%
new_set=set(number)
print(type(new_set))
# Out:
# <class 'set'>

# %%
new_set
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
student={
    "id":"1",
    "name": "ram",
    "score":"80%",
    "subject":["maths","science","english"],
    "Age":"20"

}
print(type(student))
print(student)
# Out:
# <class 'dict'>
# {'id': '1', 'name': 'ram', 'score': '80%', 'subject': ['maths', 'science', 'english'], 'Age': '20'}

# %%
new_numbers=[1,2,5,3,8,1,6,4,5]
unique_values=set(new_numbers)
print(unique_values)
reconvert_list=list(unique_values)
print(reconvert_list)
# Out:
# {1, 2, 3, 4, 5, 6, 8}
# [1, 2, 3, 4, 5, 6, 8]
