# %% [markdown]
# <a href="https://colab.research.google.com/github/dhiraj-vrit/dsml_batch_9/blob/Madan_Khanal/Day03_string.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Madan Khanal

# %%
text="Nepal is a landlocked country. Nepal is a secular country."

# %%
length = len(text)
print(length)
# Out:
# 58

# %%
count = len(text.replace(" ", ""))
print(count)
# Out:
# 49

# %%
print(text.upper())
# Out:
# NEPAL IS A LANDLOCKED COUNTRY. NEPAL IS A SECULAR COUNTRY.

# %%
print (text.count("country"))
# Out:
# 2

# %%
print(text.split())
# Out:
# ['Nepal', 'is', 'a', 'landlocked', 'country.', 'Nepal', 'is', 'a', 'secular', 'country.']

# %%
print(text.title())
# Out:
# Nepal Is A Landlocked Country. Nepal Is A Secular Country.

# %%
my_list=['Nepal', 'is', 'a', 'landlocked', 'country.', 'Nepal', 'is', 'a', 'secular', 'country.']
result = " ".join(my_list)
print(result)
# Out:
# Nepal is a landlocked country. Nepal is a secular country.
