# %% [markdown]
# <a href="https://colab.research.google.com/github/dhiraj-vrit/dsml_batch_9/blob/Madan_Khanal/Day11_Buil_in_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Madan Khanal

# %%
def num(a,b):
  return a+b
def greet( name):
  print("Hello", name)
name="Madan"
greet(name)
# Out:
# Hello Madan

# %%
greet("Madan")
# Out:
# Hello Madan

# %%
add=(num(2,3))
print (add)
# Out:
# 5

# %%
x = 5
a = float(x)
b=str(x)
c=int(x)
d=complex(x)
e=bool(x)

print(a,b,c,d,e)
# Out:
# 5.0 5 5 (5+0j) True

# %%
print(pow(2, 3))
print(abs(-20))
print(round(3.656))
print(round(3.556, 2))
# Out:
# 8
# 20
# 4
# 3.56

# %%
nums = [2, 4, 6, 7, 8]

for i in range(len(nums)):
    nums[i] = nums[i] * 2

print("Final Output : ", nums)
# Out:
# Final Output :  [4, 8, 12, 14, 16]

# %%
list1=["Madan","Manoj","Raj","Dhiraj"]
list2=["Baneshwor","Kohalpur","Butwal","Pepsicola"]
list3=[9876,123,456,235]
#for a, b, c in zip(list1, list2, list3):
    #print(a, b, c)
for index, (name, place, number) in enumerate(zip(list1, list2, list3)):
    print("Index", index, ":", name, "-", place, "-", number)
# Out:
# Index 0 : Madan - Baneshwor - 9876
# Index 1 : Manoj - Kohalpur - 123
# Index 2 : Raj - Butwal - 456
# Index 3 : Dhiraj - Pepsicola - 235
