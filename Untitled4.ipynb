# %% [markdown]
# day 5 :  LIST | TUPLE

# %%
mlist = ['PURNA', 1, 6.6, True, False, 1, 2]
print(mlist)
mlist.append("hero")
 # append only add data at the last of the list while insert can add data at any position
print(mlist)
mlist.insert(1, 67) # need to define both index value and data
print(mlist)
# Out:
# ['PURNA', 1, 6.6, True, False, 1, 2]
# ['PURNA', 1, 6.6, True, False, 1, 2, 'hero']
# ['PURNA', 67, 1, 6.6, True, False, 1, 2, 'hero']

# %%
mylist = [1, 1.1, True, "purna", False, 50]
alist = [1, 60, 90, 2, 5]
print(mylist.pop(3))
alist.sort()
print(alist)
# Out:
# purna
# [1, 2, 5, 60, 90]

# %%
mylist = [1, 1.1, True, "purna", False, 50]
mylist.clear()
print(mylist)
alist = [1, 60, 90, 2, 5]
alist.remove(60)
print(alist)
alist.reverse()
print(alist)
# Out:
# []
# [1, 90, 2, 5]
# [5, 2, 90, 1]

# %%
listA = [150, 120, 100, 165, 190, 145, 182, 175, 17]
print(sorted(listA))
print(sorted(listA, reverse = False))
# Out:
# [17, 100, 120, 145, 150, 165, 175, 182, 190]
# [17, 100, 120, 145, 150, 165, 175, 182, 190]

# %%
listA = [190, 150, 190, 120, 100, 165, 190, 145, 182, 175, 17, 150]
print(listA.count(190))
print(listA.index(190))
# Out:
# 3
# 0

# %%
listA = [190, 150, 190, 120, 100, 165, 190, 145, 182, 175, 17, 150]
copy = listA.copy()
print(copy)
print(type(copy))
# Out:
# [190, 150, 190, 120, 100, 165, 190, 145, 182, 175, 17, 150]
# <class 'list'>

# %%
listA = [190, 150, 190, 120, 100, 165, 190, 145, 182, 175, 17, 150]
listA.sort()
print(listA)
print(max(listA))
print(min(listA))
print(sum(listA))
print(len(listA))
# Out:
# [17, 100, 120, 145, 150, 150, 165, 175, 182, 190, 190, 190]
# 190
# 17
# 1774
# 12

# %%
t = (4, 9, 'purna', 9.8, True, 9)
t1 = (5, 0, 6, 'lama', True)
print(t + t1)
print(t * 3)
# Out:
# (4, 9, 'purna', 9.8, True, 9, 5, 0, 6, 'lama', True)
# (4, 9, 'purna', 9.8, True, 9, 4, 9, 'purna', 9.8, True, 9, 4, 9, 'purna', 9.8, True, 9)

# %%
t = (5, 7, 7)
t.append(67) # can't do because tuples are immutable

# %%
t = (4, 9, 'purna', 9.8, True, 9)
print(t[::2])
# Out:
# (4, 'purna', True)

# %%
t = (4, 9, 'purna', 9.8, True, 9)
t1 = (5, 0, 6, 'lama', True)
print(t == t1)
# Out:
# False

# %%
t3 = (4, 9, 'purna', 9.8, True, 9)
print(100 not in t3)
print(4 in t3)
# Out:
# True
# True

# %%
tuper = (1, 8, 90, 60, 56, 23, 60, 23)
print(max(tuper))
print(min(tuper))
# tuper.sort() can't
# print(tuper)
# Out:
# 90
# 1

# %% [markdown]
# set | IMMUATBLE

# %%
myset = {1, 60, 80, 90, 60}
print(myset)
# myset.insert(90) not allowed because set are immutable
#  print(myset * 2)
myset.remove(90)
print(myset)
myset.clear()
print(myset)
# Out:
# {80, 1, 90, 60}
# {80, 1, 60}
# set()

# %%
a = { }
print(type(a))
b= []
print(type(b))
c = ()
print(type(c))
d = set()
print(type(d))
print(type(bool))
print(type(-1))
print(type(int))
print(type(float))
# Out:
# <class 'dict'>
# <class 'list'>
# <class 'tuple'>
# <class 'set'>
# <class 'type'>
# <class 'int'>
# <class 'type'>
# <class 'type'>

# %%
check = ['my', 'hello', 90, 69, 80, 8.8]

# %% [markdown]
# Dict

# %%
mydict = [{
    "id" : 1234,
    "name ": "purna",
    "age" : 20,
   " gender ": "male"
},
        {
    "id" : 1235,
    "name " : "sing",
    "age" : 19,
    "gender" : "female"
}]
print(mydict)
print(mydict[0])
print(mydict[1])
print(mydict[1]["name "])
# Out:
# [{'id': 1234, 'name ': 'purna', 'age': 20, ' gender ': 'male'}, {'id': 1235, 'name ': 'sing', 'age': 19, 'gender': 'female'}]
# {'id': 1234, 'name ': 'purna', 'age': 20, ' gender ': 'male'}
# {'id': 1235, 'name ': 'sing', 'age': 19, 'gender': 'female'}
# sing

# %%
mydict = [{
    "id" : 1234,
    "name ": "purna",
    "age" : 20,
   " gender ": "male"
},
        {
    "id" : 1235,
    "name " : "sing",
    "age" : 19,
    "gender" : "female"
}]
dicto = {
    " name " : "purna",
    "age" : 20,
   " gender ": "male"
}
print(mydict)
print(dicto.items())
# Out:
# [{'id': 1234, 'name ': 'purna', 'age': 20, ' gender ': 'male'}, {'id': 1235, 'name ': 'sing', 'age': 19, 'gender': 'female'}]
# dict_items([(' name ', 'purna'), ('age', 20), (' gender ', 'male')])
