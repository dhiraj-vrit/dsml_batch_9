# %% [markdown]
# <a href="https://colab.research.google.com/github/dhiraj-vrit/dsml_batch_9/blob/Madan_Khanal/Day07_Condition_and_Branching.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Madan Khanal

# %%
number = int(input("Enter a number: "))

if number % 2 == 0:
    print("Number is even.")
else:
    print("Number is odd.")

# %%
name= input("Enter your name: ")
age= int(input("Enter your age: "))
ctz=(input("Are you a citizen? (yes/no): "))
if age>=18 and ctz=="yes":
  print("You are eligible to vote")
  print("Your vote has been listed")
else:
  print("You are not eligible to vote")

#if ctz=="yes":
  #print("You are a citizen")
#else:
  #print("You are not a citizen")

# %%
number1 = int(input("Enter a number: "))
if number1 % 1 == 0 :
  print("Number is prime")
else:
  print("Number is not prime")

# %%
num1= int(input("Enter First number: "))
num2= int(input("Enter Second number: "))
num3= int(input("Enter Third number: "))
if (num1>num2 and num1>num3):
  print("The largest number is First Number:",num1)
elif num2>num3 and num2>num1:
  print("The largest number is Second Number:",num2)
else:
  print("The largest number is Third Number",num3)

# %%
Grade= int(input("Enter your Percentage: "))
if Grade>=90:
  print("Your grade is A+")
  print("You Have Score 4.0 GPA")
  print("Excellent")
elif Grade>=80:
  print("Your grade is A")
  print("You Have Score above 3.2 to 3.6 GPA")
  print("Very Good")
elif Grade>=70:
  print("Your grade is B+")
  print("You Have Score above 2.8 to 3.2 GPA")
  print("Good")
elif Grade>=60:
  print("Your grade is B")
  print("You Have Score above 2.4 to 2.8 GPA")
  print("Pass")
elif Grade>=50:
  print("Your grade is C+")
  print("You Have Score above 2.0 to 2.4 GPA")
  print("Work hard")
else:
  print("Please Input proper Percentage.")

# %%
GPA=
