# %%
x=8
y=3.2
a=3+8j
z=x+y

# %%
print(type(x))
print(type(y))
print(type(a))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
add=(x+y)
sub=(x-y)
multp=(x*y)
divi=(x/y)

# %%
print(add,sub,multp,divi)
# Out:
# 11.2 4.8 25.6 2.5

# %%
power=(x**y)
print(power)
# Out:
# 776.0468820533241

# %%
print(x//y)
# Out:
# 2.0

# %%
print(x%y)
# Out:
# 1.5999999999999996

# %%
print(int(y))
# Out:
# 3

# %%
print(complex(y))
# Out:
# (3.2+0j)
