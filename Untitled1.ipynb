# %% [markdown]
# DAY 3 : PYTHON STRING

# %%
string = 'string1'
print(type(string))
# Out:
# <class 'str'>

# %%
str = "string"
print(type(str))
# Out:
# <class 'str'>

# %%
str = 'python'
print(str[0])
print(str[-6])
# Out:
# p
# p

# %%
dataA = 'string'
dataB = "string"
dataC = '''string'''
print(dataA == dataB == dataC)
# Out:
# True

# %%
str = 'python '
str2 = ' learning'
print(str * 3)
print(str + str2)
print(len(str))
# Out:
# python python python
# python  learning
# 7

# %%
str = 'hello world'
print(len(str))
# Out:
# 11

# %%
str = 'hello'
print(str[0 :  3])
# Out:
# hel

# %%
str = 'hello python'
str2 = 'world is the best place to live'
print(str.upper())
print(str.lower())
print(str2.title())
print(str.strip())
# print(str.join())
# print(str.())
# Out:
# HELLO PYTHON
# hello python
# World Is The Best Place To Live
# hello python

# %%
str = 'purna.png'
str2 = str.startswith("purna")
str3 = str.endswith(".")
print(str2)
print(str3)
# Out:
# True
# False

# %%
data  = 10
data2 = '10'
print(type(data))
print(type(data2))
# Out:
# <class 'int'>
# <class 'str'>

# %%
var1 = 'purna sing tamang'
var2 = var1.replace(' ', '_')
print(var2)
# Out:
# purna_sing_tamang

# %%
var= 'purna sing tamang sing'
var_a = var.count('sing')
print(var_a)
print(var.count(''))
# Out:
# 2
# 23

# %%
a = '''
hello world i'm here to present my python skill in front of everyone to kill one the above one tho is not and not able to
introduce the whole killing machine who can't code on python and is a very dangerous code whihch makes people to scred of the pytho
and many college and universities will not abble to understand how python works and how to defaeat againest the python . python is a very stringn
programming language
    '''
print(a[0: len(a): 5 ])
print(a[::-2])
# Out:
# olmepn oinn ytle e it atnuhoighwacotaseaooh spoe p   enii  a nthy s tf nty tivsgomla
#
# eaga nmagr
# git rvas otp.nhy h snaatefdo o n ko otpwhdasen tebatnli etseiudaeelcya n
# otpetf ec tepe ea ciweo urga rvas n otpn dctncoweicmgilkeoweteuoti teb o n o ioteoeoaeteoli teorv otofn lk otpy nsr tee ' lo le
